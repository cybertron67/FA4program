# %% [markdown]
# <a href="https://colab.research.google.com/github/cybertron67/FA4program/blob/main/FA4Program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#skip even numbers

count = 0

while count <= 20:
  if count % 2 == 1:
    print(count)
  count += 1

# %%
#password thingy

password = int(input("Please Enter Your 6 Digit Password"))
code = 123456

while code != password:
  print("Wrong Password Try Again!")
  password = int(input("Please Enter Your 6 Digit Password"))
print("Correct Password Access Granted")

# %%
#fa4

for number in range(1, 10):
     if number == 4:
      continue
     elif number == 6:
      pass
     elif number == 8:
      break
     print(number)
